# %% [markdown]
# ### Bayesian Optimization을 이용하여 application과 previous로 만들어진 집합의 하이퍼 파라미터 튜닝

# %% [markdown]
# #### 라이브러리 및 데이터 세트 로딩. 이전 application 데이터의 FE 함수 복사

# %%
import numpy as np
import pandas as pd
import gc  # 가비지 컬렉션
import time
import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline

pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ##### 코랩 버전은 Google Drive에서 데이터 세트를 로딩

# %%
import os, sys
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
def get_dataset():
  """
  현재 대출신청정보와 이전 대출이력정보 리턴 
  """
  default_dir = "/content/gdrive/My Drive"
  app_train = pd.read_csv(os.path.join(default_dir, 'application_train.csv'))
  app_test = pd.read_csv(os.path.join(default_dir, 'application_test.csv'))
  apps = pd.concat([app_train, app_test])
  prev = pd.read_csv(os.path.join(default_dir, 'previous_application.csv'))
  
  return apps, prev

apps, prev = get_dataset()

# %% [markdown]
# #### 이전 application 데이터의 feature engineering 함수 복사

# %%
def get_apps_processed(apps):
    """
    현재 대출이력(훈련용, 테스트용 병합)
    apps의 주요 피처 가공값 생성

    1.EXT_SOURCE_1,EXT_SOURCE_2, EXT_SOURCE_3(평균, 표준편차)
    2.APPS_EXT_SOURCE_STD(평균값)
    3.APPS_ANNUITY_CREDIT_RATIO : 대출금액 대비 매월 갚아야 할 하는 납부금액 비율(AMT_ANNUITY / AMT_CREDIT)
    4.APPS_GOODS_CREDIT_RATIO   : 대출금액 대비 고객상품대출금액 비율(AMT_GOODS_PRICE / AMT_CREDIT)
    5.APPS_ANNUITY_INCOME_RATIO : 소득대비 매월 갚아야 하는 금액의 비율(AMT_ANNUITY / AMT_INCOME_TOTAL)
    6.APPS_CREDIT_INCOME_RATIO :  소득대비 대출금액의 비율(AMT_CREDIT / AMT_INCOME_TOTAL)
    7.APPS_GOODS_INCOME_RATIO   : 소득대비 대출상품금액의 비율(AMT_GOODS_PRICE / AMT_INCOME_TOTAL)
    8.APPS_CNT_FAM_INCOME_RATIO : 가족수 대비 소득금액비율(AMT_INCOME_TOTAL / CNT_FAM_MEMBERS)
    9.APPS_EMPLOYED_BIRTH_RATIO : 연령대비 재직기간 비율(DAYS_EMPLOYEED / DAYS_BIRTH)
    10.APPS_INCOME_EMPLOYED_RATIO : 재직기간 대비 소득비율(AMT_INCOME_TOTAL / DAYS_EMPLOYEED)
    11.APPS_INCOME_BIRTH_RATIO    : 연령대비 소득비율(AMT_INCOME_TOTAL / DAYS_BIRTH)
    12.APPS_CAR_BIRTH_RATIO    : 연령대비 소유차의 연식( OWN_CAR_AGE / DAYS_BIRTH)
    13.APPS_CAR_EMPLOYED_RATIO : 재직기간대비 소유차의 연식(OWN_CAR_AGE / DAYS_EMPLOYEED)
    """
    # EXT_SOURCE_X FEATURE 가공
    apps['APPS_EXT_SOURCE_MEAN'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    apps['APPS_EXT_SOURCE_STD'] = apps['APPS_EXT_SOURCE_STD'].fillna(apps['APPS_EXT_SOURCE_STD'].mean())
    
    # AMT_CREDIT 비율로 Feature 가공
    apps['APPS_ANNUITY_CREDIT_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_CREDIT']
    apps['APPS_GOODS_CREDIT_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_CREDIT']
    
    # AMT_INCOME_TOTAL 비율로 Feature 가공
    apps['APPS_ANNUITY_INCOME_RATIO'] = apps['AMT_ANNUITY']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CREDIT_INCOME_RATIO'] = apps['AMT_CREDIT']/apps['AMT_INCOME_TOTAL']
    apps['APPS_GOODS_INCOME_RATIO'] = apps['AMT_GOODS_PRICE']/apps['AMT_INCOME_TOTAL']
    apps['APPS_CNT_FAM_INCOME_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['CNT_FAM_MEMBERS']
    
    # DAYS_BIRTH, DAYS_EMPLOYED 비율로 Feature 가공
    apps['APPS_EMPLOYED_BIRTH_RATIO'] = apps['DAYS_EMPLOYED']/apps['DAYS_BIRTH']
    apps['APPS_INCOME_EMPLOYED_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_EMPLOYED']
    apps['APPS_INCOME_BIRTH_RATIO'] = apps['AMT_INCOME_TOTAL']/apps['DAYS_BIRTH']
    apps['APPS_CAR_BIRTH_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_BIRTH']
    apps['APPS_CAR_EMPLOYED_RATIO'] = apps['OWN_CAR_AGE'] / apps['DAYS_EMPLOYED']
    
    return apps

# %% [markdown]
# #### previous 데이터 가공후 인코딩 및 최종 데이터 집합 생성하는 함수 선언

# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMClassifier

def get_prev_processed(prev):
    # 대출 신청 금액과 실제 대출액/대출 상품금액 차이 및 비율
    """
    과거대출이력 데이터 
    1.PREV_CREDIT_DIFF : 대출금액과 대출신청금액의 차이(AMT_APPLICATION - AMT_CREDIT)
    2.PREV_GOODS_DIFF : 대출신청금액과 상품대출금액의 차(AMT_APPLICATION - AMT_GOODS_PRICE)
    3.PREV_CREDIT_APPL_RATIO : 대출금액 / 대출신청금액(AMT_CREDIT / AMT_APPLICATION)
    4.PREV_GOODS_APPL_RATIO : 고객상품대출금액 / 대출신청금액(AMT_GOODS_PRICE / AMT_APPLICATION)
    """
    prev['PREV_CREDIT_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_CREDIT']
    prev['PREV_GOODS_DIFF'] = prev['AMT_APPLICATION'] - prev['AMT_GOODS_PRICE']
    prev['PREV_CREDIT_APPL_RATIO'] = prev['AMT_CREDIT']/prev['AMT_APPLICATION']
    # prev['PREV_ANNUITY_APPL_RATIO'] = prev['AMT_ANNUITY']/prev['AMT_APPLICATION']
    prev['PREV_GOODS_APPL_RATIO'] = prev['AMT_GOODS_PRICE']/prev['AMT_APPLICATION']
    
    # 널값 정제 
    prev['DAYS_FIRST_DRAWING'].replace(365243, np.nan, inplace= True)
    prev['DAYS_FIRST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE_1ST_VERSION'].replace(365243, np.nan, inplace= True)
    prev['DAYS_LAST_DUE'].replace(365243, np.nan, inplace= True)
    prev['DAYS_TERMINATION'].replace(365243, np.nan, inplace= True)
    # 첫번째 만기일과 마지막 만기일까지의 기간

    prev['PREV_DAYS_LAST_DUE_DIFF'] = prev['DAYS_LAST_DUE_1ST_VERSION'] - prev['DAYS_LAST_DUE']
    
    # 매월 납부 금액과 납부 횟수 곱해서 전체 납부 금액 구함. 
    # 이자율 계산
    all_pay = prev['AMT_ANNUITY'] * prev['CNT_PAYMENT']
    # 전체 납부 금액 대비 AMT_CREDIT 비율을 구하고 여기에 다시 납부횟수로 나누어서 이자율 계산. 
    prev['PREV_INTERESTS_RATE'] = (all_pay/prev['AMT_CREDIT'] - 1)/prev['CNT_PAYMENT']
        
    return prev
    
    
def get_prev_amt_agg(prev):
    # 새롭게 생성된 대출 신청액 대비 다른 금액 차이 및 비율로 aggregation 수행. 
    """
    과거대출이력의 데이터에 대한 일부 컬럼에 대한 집계 파생변수 생성
    """
    agg_dict = {
         # 기존 컬럼. 
        'SK_ID_CURR':['count'],
        'AMT_CREDIT':['mean', 'max', 'sum'],
        'AMT_ANNUITY':['mean', 'max', 'sum'], 
        'AMT_APPLICATION':['mean', 'max', 'sum'],
        'AMT_DOWN_PAYMENT':['mean', 'max', 'sum'],
        'AMT_GOODS_PRICE':['mean', 'max', 'sum'],
        'RATE_DOWN_PAYMENT': ['min', 'max', 'mean'],
        'DAYS_DECISION': ['min', 'max', 'mean'],
        'CNT_PAYMENT': ['mean', 'sum'],
        # 가공 컬럼
        'PREV_CREDIT_DIFF':['mean', 'max', 'sum'], 
        'PREV_CREDIT_APPL_RATIO':['mean', 'max'],
        'PREV_GOODS_DIFF':['mean', 'max', 'sum'],
        'PREV_GOODS_APPL_RATIO':['mean', 'max'],
        'PREV_DAYS_LAST_DUE_DIFF':['mean', 'max', 'sum'],
        'PREV_INTERESTS_RATE':['mean', 'max']
    }
    prev_group = prev.groupby('SK_ID_CURR')
    prev_amt_agg = prev_group.agg(agg_dict)

    # multi index 컬럼을 '_'로 연결하여 컬럼명 변경
    prev_amt_agg.columns = ["PREV_"+ "_".join(x).upper() for x in prev_amt_agg.columns.ravel()]
    
    return prev_amt_agg

def get_prev_refused_appr_agg(prev):
  """
  과거 대출건중에서 승인된건 , 거부된 건수 
  """
  # 원래 groupby 컬럼 + 세부 기준 컬럼으로 groupby 수행. 세분화된 레벨로 aggregation 수행 한 뒤에 unstack()으로 컬럼레벨로 변형. 
  prev_refused_appr_group = prev[prev['NAME_CONTRACT_STATUS'].isin(['Approved', 'Refused'])].groupby(['SK_ID_CURR', 'NAME_CONTRACT_STATUS'])
  prev_refused_appr_agg = prev_refused_appr_group['SK_ID_CURR'].count().unstack()
  # 컬럼명 변경. 
  prev_refused_appr_agg.columns = ['PREV_APPROVED_COUNT', 'PREV_REFUSED_COUNT' ]
  # NaN값은 모두 0으로 변경. 
  prev_refused_appr_agg = prev_refused_appr_agg.fillna(0)  
  return prev_refused_appr_agg

def get_prev_agg(prev):
  """
  1.과거대출 이력건에 대한 파생변수 생성
  2.과거 대출건의 승인 및 거부건수 비율 집합 생성
  3.1)번과 2번 LEFT조인해서 리턴
  """
  prev = get_prev_processed(prev)
  prev_amt_agg = get_prev_amt_agg(prev)
  prev_refused_appr_agg = get_prev_refused_appr_agg(prev)
  
  # prev_amt_agg와 조인. 
  prev_agg = prev_amt_agg.merge(prev_refused_appr_agg, on='SK_ID_CURR', how='left')
  # SK_ID_CURR별 과거 대출건수 대비 APPROVED_COUNT 및 REFUSED_COUNT 비율 생성. 
  prev_agg['PREV_REFUSED_RATIO'] = prev_agg['PREV_REFUSED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
  prev_agg['PREV_APPROVED_RATIO'] = prev_agg['PREV_APPROVED_COUNT']/prev_agg['PREV_SK_ID_CURR_COUNT']
  # 'PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT' 컬럼 drop 
  prev_agg = prev_agg.drop(['PREV_REFUSED_COUNT', 'PREV_APPROVED_COUNT'], axis=1)
  
  return prev_agg

def get_apps_all_with_prev_agg(apps, prev):
  """
  집계된 데이터 리넡
  """
  apps_all =  get_apps_processed(apps)
  prev_agg = get_prev_agg(prev)
  print('prev_agg shape:', prev_agg.shape)
  print('apps_all before merge shape:', apps_all.shape)
  apps_all = apps_all.merge(prev_agg, on='SK_ID_CURR', how='left')
  print('apps_all after merge with prev_agg shape:', apps_all.shape)
  
  return apps_all

def get_apps_all_encoded(apps_all):
  """
  범주형변수의 인코딩
  """
  object_columns = apps_all.dtypes[apps_all.dtypes == 'object'].index.tolist()
  for column in object_columns:
      apps_all[column] = pd.factorize(apps_all[column])[0]
  
  return apps_all

def get_apps_all_train_test(apps_all):
  """
  train, test셋 분리 
  """
  apps_all_train = apps_all[~apps_all['TARGET'].isnull()]
  apps_all_test = apps_all[apps_all['TARGET'].isnull()]

  apps_all_test = apps_all_test.drop('TARGET', axis=1)
  
  return apps_all_train, apps_all_test
    
def train_apps_all(apps_all_train):
  """
  LGBMClassifier로 fit
  """
  ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
  target_app = apps_all_train['TARGET']

  train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
  print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
  clf = LGBMClassifier(
              nthread=4,
              n_estimators=2000,
              learning_rate=0.01,
              num_leaves=32,
              colsample_bytree=0.8,
              subsample=0.8,
              max_depth=8,
              reg_alpha=0.04,
              reg_lambda=0.07,
              min_child_weight=40,
              silent=-1,
              verbose=-1,
              )

  clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
              early_stopping_rounds= 100)
  
  return clf

# %% [markdown]
# ##### 최종 집합 생성 및 인코딩, 학습/테스트 데이터 분리, 학습/검증 피처와 타겟 데이터 분리

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
target_app = apps_all_train['TARGET']
train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)

# %% [markdown]
# #### Bayesian Optimization

# %%
# bayesian optimization 패키지 설치
# !pip install bayesian-optimization
# Out:
# Collecting bayesian-optimization
#   Downloading https://files.pythonhosted.org/packages/bb/7a/fd8059a3881d3ab37ac8f72f56b73937a14e8bb14a9733e68cc8b17dbe3c/bayesian-optimization-1.2.0.tar.gz
# Requirement already satisfied: numpy>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.19.5)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (1.4.1)
# Requirement already satisfied: scikit-learn>=0.18.0 in /usr/local/lib/python3.7/dist-packages (from bayesian-optimization) (0.22.2.post1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.18.0->bayesian-optimization) (1.0.1)
# Building wheels for collected packages: bayesian-optimization
#   Building wheel for bayesian-optimization (setup.py) ... done
#   Created wheel for bayesian-optimization: filename=bayesian_optimization-1.2.0-cp37-none-any.whl size=11687 sha256=9d3b82d37b112d1f736d912afd9c0b7c8dd893f79821f076caa34f44ab21d4c5
#   Stored in directory: /root/.cache/pip/wheels/5a/56/ae/e0e3c1fc1954dc3ec712e2df547235ed072b448094d8f94aec
# Successfully built bayesian-optimization
# Installing collected packages: bayesian-optimization
# Successfully installed bayesian-optimization-1.2.0

# %% [markdown]
# ### Bayesian Optimization

# %%
from bayes_opt import BayesianOptimization
from sklearn.metrics import roc_auc_score
from lightgbm import LGBMClassifier

# %% [markdown]
# ##### **함수의 입력값 search 범위(하이퍼 파라미터 별 입력 범위) 를 설정**

# %%
bayesian_params = {
    'max_depth': (6, 16),
    'num_leaves':(24,  64),
    'min_child_samples': (10, 200),
    'min_child_weight': (1, 50),
    'subsamples': (0.5, 1),  # 0부터 1까지의 범위를 가짐
    'colsample_bytree': (0.5, 1),
    'max_bin': (10, 500), 
    'reg_lambda': (0.001, 10),
    'reg_alpha': (0.01, 50)
    }

# %% [markdown]
# ##### **최대 값을 구할 함수 선언.**
# * iteration 시 마다 hyperparameter를 입력받아 classifier 학습하고 roc_auc_score값을 반환

# %%
def lgb_roc_eval(max_depth, num_leaves, min_child_samples, min_child_weight, 
                 subsamples, colsample_bytree, max_bin, reg_lambda, reg_alpha):
  params = {
      "n_estimators":500, "learning_rate":0.02,
      'max_depth': int(round(max_depth)),
      'num_leaves': int(round(num_leaves)), 
      'min_child_samples': int(round(min_child_samples)),
      'min_child_weight': int(round(min_child_weight)),
      'subsamples':max(min(subsamples, 1), 0),
      'colsample_bytree':max(min(colsample_bytree, 1), 0),
      'max_bin':  max(int(round(max_bin)),10),
      'reg_lambda': max(reg_lambda,0),
      'reg_alpha': max(reg_alpha, 0)
  }
  lgb_model = LGBMClassifier(**params)
  lgb_model.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
  valid_proba = lgb_model.predict_proba(valid_x)[:, 1]
  roc_auc = roc_auc_score(valid_y, valid_proba)
  
  return roc_auc

# %% [markdown]
# ##### BayesianOptimization 객체 생성 후 **함수 반환값이 최대가 되는 입력값 search**를 위한 iteration 수행

# %%
# BayesianOptimization객체를 수행할 함수와 search할 parameter 범위를 설정하여 생성. 
lgbBO = BayesianOptimization(lgb_roc_eval,bayesian_params , random_state=0)
# 함수 반환값이 최대가 되는 입력값 유추를 위한 iteration 수행. 
lgbBO.maximize(init_points=5, n_iter=25)
# Out:
# |   iter    |  target   | colsam... |  max_bin  | max_depth | min_ch... | min_ch... | num_le... | reg_alpha | reg_la... | subsam... |
# -------------------------------------------------------------------------------------------------------------------------------------
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.769441	training's binary_logloss: 0.246055	valid_1's auc: 0.755295	valid_1's binary_logloss: 0.248931
# [200]	training's auc: 0.787337	training's binary_logloss: 0.238455	valid_1's auc: 0.766208	valid_1's binary_logloss: 0.244205
# [300]	training's auc: 0.798843	training's binary_logloss: 0.234009	valid_1's auc: 0.771365	valid_1's binary_logloss: 0.242347
# [400]	training's auc: 0.807905	training's binary_logloss: 0.230658	valid_1's auc: 0.773881	valid_1's binary_logloss: 0.241451
# [500]	training's auc: 0.816051	training's binary_logloss: 0.227681	valid_1's auc: 0.775474	valid_1's binary_logloss: 0.240888
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816051	training's binary_logloss: 0.227681	valid_1's auc: 0.775474	valid_1's binary_logloss: 0.240888
# |  1        |  0.7755   |  0.7744   |  360.4    |  12.03    |  113.5    |  21.76    |  49.84    |  21.88    |  8.918    |  0.9818   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.762607	training's binary_logloss: 0.247403	valid_1's auc: 0.753906	valid_1's binary_logloss: 0.249078
# [200]	training's auc: 0.780221	training's binary_logloss: 0.240422	valid_1's auc: 0.765727	valid_1's binary_logloss: 0.244242
# [300]	training's auc: 0.790896	training's binary_logloss: 0.236479	valid_1's auc: 0.77103	valid_1's binary_logloss: 0.242327
# [400]	training's auc: 0.799101	training's binary_logloss: 0.233521	valid_1's auc: 0.773901	valid_1's binary_logloss: 0.2413
# [500]	training's auc: 0.805962	training's binary_logloss: 0.231078	valid_1's auc: 0.775357	valid_1's binary_logloss: 0.240762
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805962	training's binary_logloss: 0.231078	valid_1's auc: 0.775357	valid_1's binary_logloss: 0.240762
# |  2        |  0.7754   |  0.6917   |  397.9    |  11.29    |  117.9    |  46.35    |  26.84    |  4.366    |  0.2032   |  0.9163   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.775984	training's binary_logloss: 0.243787	valid_1's auc: 0.757669	valid_1's binary_logloss: 0.247887
# [200]	training's auc: 0.797205	training's binary_logloss: 0.234957	valid_1's auc: 0.769013	valid_1's binary_logloss: 0.243121
# [300]	training's auc: 0.812302	training's binary_logloss: 0.22917	valid_1's auc: 0.773828	valid_1's binary_logloss: 0.241429
# [400]	training's auc: 0.824959	training's binary_logloss: 0.224408	valid_1's auc: 0.776324	valid_1's binary_logloss: 0.240536
# [500]	training's auc: 0.835945	training's binary_logloss: 0.220334	valid_1's auc: 0.777332	valid_1's binary_logloss: 0.240167
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.835945	training's binary_logloss: 0.220334	valid_1's auc: 0.777332	valid_1's binary_logloss: 0.240167
# |  3        |  0.7773   |  0.8891   |  436.3    |  15.79    |  161.8    |  23.61    |  55.22    |  5.923    |  6.4      |  0.5717   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.765744	training's binary_logloss: 0.246899	valid_1's auc: 0.753886	valid_1's binary_logloss: 0.249215
# [200]	training's auc: 0.782824	training's binary_logloss: 0.239831	valid_1's auc: 0.765228	valid_1's binary_logloss: 0.24453
# [300]	training's auc: 0.79353	training's binary_logloss: 0.235787	valid_1's auc: 0.770618	valid_1's binary_logloss: 0.2426
# [400]	training's auc: 0.801566	training's binary_logloss: 0.232814	valid_1's auc: 0.773499	valid_1's binary_logloss: 0.241576
# [500]	training's auc: 0.808263	training's binary_logloss: 0.230355	valid_1's auc: 0.774994	valid_1's binary_logloss: 0.241041
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.808263	training's binary_logloss: 0.230355	valid_1's auc: 0.774994	valid_1's binary_logloss: 0.241041
# |  4        |  0.775    |  0.9723   |  265.7    |  10.15    |  60.27    |  38.94    |  42.25    |  28.43    |  0.1889   |  0.8088   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.765749	training's binary_logloss: 0.247324	valid_1's auc: 0.753702	valid_1's binary_logloss: 0.249617
# [200]	training's auc: 0.781611	training's binary_logloss: 0.240353	valid_1's auc: 0.764481	valid_1's binary_logloss: 0.244878
# [300]	training's auc: 0.791576	training's binary_logloss: 0.236528	valid_1's auc: 0.769669	valid_1's binary_logloss: 0.242979
# [400]	training's auc: 0.799079	training's binary_logloss: 0.233771	valid_1's auc: 0.772325	valid_1's binary_logloss: 0.242037
# [500]	training's auc: 0.805611	training's binary_logloss: 0.231415	valid_1's auc: 0.774198	valid_1's binary_logloss: 0.241404
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.805611	training's binary_logloss: 0.231415	valid_1's auc: 0.774198	valid_1's binary_logloss: 0.241404
# |  5        |  0.7742   |  0.806    |  312.3    |  15.44    |  139.5    |  18.62    |  41.48    |  34.88    |  0.6032   |  0.8334   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.765974	training's binary_logloss: 0.24729	valid_1's auc: 0.753298	valid_1's binary_logloss: 0.249608
# [200]	training's auc: 0.782182	training's binary_logloss: 0.240351	valid_1's auc: 0.764937	valid_1's binary_logloss: 0.244735
# [300]	training's auc: 0.791597	training's binary_logloss: 0.236658	valid_1's auc: 0.770094	valid_1's binary_logloss: 0.242811
# [400]	training's auc: 0.798618	training's binary_logloss: 0.234003	valid_1's auc: 0.772785	valid_1's binary_logloss: 0.241848
# [500]	training's auc: 0.80432	training's binary_logloss: 0.231862	valid_1's auc: 0.774314	valid_1's binary_logloss: 0.241265
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.80432	training's binary_logloss: 0.231862	valid_1's auc: 0.774314	valid_1's binary_logloss: 0.241265
# |  6        |  0.7743   |  0.8538   |  499.2    |  7.119    |  10.4     |  37.64    |  46.75    |  34.55    |  7.535    |  0.7468   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.765969	training's binary_logloss: 0.246977	valid_1's auc: 0.753264	valid_1's binary_logloss: 0.249416
# [200]	training's auc: 0.78383	training's binary_logloss: 0.239697	valid_1's auc: 0.76387	valid_1's binary_logloss: 0.244979
# [300]	training's auc: 0.795076	training's binary_logloss: 0.235487	valid_1's auc: 0.768285	valid_1's binary_logloss: 0.243362
# [400]	training's auc: 0.804034	training's binary_logloss: 0.232212	valid_1's auc: 0.770586	valid_1's binary_logloss: 0.242589
# [500]	training's auc: 0.812016	training's binary_logloss: 0.22931	valid_1's auc: 0.772006	valid_1's binary_logloss: 0.242104
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.812016	training's binary_logloss: 0.22931	valid_1's auc: 0.772006	valid_1's binary_logloss: 0.242104
# |  7        |  0.772    |  0.9751   |  12.5     |  15.87    |  199.1    |  43.33    |  53.78    |  14.98    |  9.61     |  0.7368   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.772591	training's binary_logloss: 0.245827	valid_1's auc: 0.757999	valid_1's binary_logloss: 0.248613
# [200]	training's auc: 0.788947	training's binary_logloss: 0.23821	valid_1's auc: 0.767444	valid_1's binary_logloss: 0.243834
# [300]	training's auc: 0.800036	training's binary_logloss: 0.233809	valid_1's auc: 0.772049	valid_1's binary_logloss: 0.242037
# [400]	training's auc: 0.807812	training's binary_logloss: 0.230765	valid_1's auc: 0.774289	valid_1's binary_logloss: 0.241178
# [500]	training's auc: 0.815026	training's binary_logloss: 0.228071	valid_1's auc: 0.775654	valid_1's binary_logloss: 0.240678
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.815026	training's binary_logloss: 0.228071	valid_1's auc: 0.775654	valid_1's binary_logloss: 0.240678
# |  8        |  0.7757   |  0.5607   |  497.7    |  7.087    |  199.5    |  48.53    |  46.57    |  8.796    |  5.276    |  0.8411   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.760337	training's binary_logloss: 0.248462	valid_1's auc: 0.751039	valid_1's binary_logloss: 0.25014
# [200]	training's auc: 0.776251	training's binary_logloss: 0.241973	valid_1's auc: 0.762675	valid_1's binary_logloss: 0.245444
# [300]	training's auc: 0.785699	training's binary_logloss: 0.238475	valid_1's auc: 0.768207	valid_1's binary_logloss: 0.24349
# [400]	training's auc: 0.792287	training's binary_logloss: 0.236043	valid_1's auc: 0.771064	valid_1's binary_logloss: 0.242475
# [500]	training's auc: 0.797673	training's binary_logloss: 0.234105	valid_1's auc: 0.772756	valid_1's binary_logloss: 0.241873
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.797673	training's binary_logloss: 0.234105	valid_1's auc: 0.772756	valid_1's binary_logloss: 0.241873
# |  9        |  0.7728   |  0.9722   |  497.8    |  15.76    |  197.6    |  5.0      |  32.35    |  43.15    |  0.1655   |  0.6483   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.770519	training's binary_logloss: 0.246026	valid_1's auc: 0.758188	valid_1's binary_logloss: 0.24849
# [200]	training's auc: 0.787168	training's binary_logloss: 0.238356	valid_1's auc: 0.768022	valid_1's binary_logloss: 0.243546
# [300]	training's auc: 0.799067	training's binary_logloss: 0.233805	valid_1's auc: 0.772513	valid_1's binary_logloss: 0.241798
# [400]	training's auc: 0.808398	training's binary_logloss: 0.230316	valid_1's auc: 0.775054	valid_1's binary_logloss: 0.24088
# [500]	training's auc: 0.816777	training's binary_logloss: 0.227288	valid_1's auc: 0.776491	valid_1's binary_logloss: 0.24038
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.816777	training's binary_logloss: 0.227288	valid_1's auc: 0.776491	valid_1's binary_logloss: 0.24038
# |  10       |  0.7765   |  0.5342   |  489.9    |  8.998    |  10.21    |  39.73    |  36.51    |  1.809    |  5.04     |  0.5383   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.780728	training's binary_logloss: 0.242511	valid_1's auc: 0.759611	valid_1's binary_logloss: 0.247498
# [200]	training's auc: 0.803019	training's binary_logloss: 0.232956	valid_1's auc: 0.769376	valid_1's binary_logloss: 0.242928
# [300]	training's auc: 0.819394	training's binary_logloss: 0.226632	valid_1's auc: 0.773595	valid_1's binary_logloss: 0.241396
# [400]	training's auc: 0.833168	training's binary_logloss: 0.221355	valid_1's auc: 0.775995	valid_1's binary_logloss: 0.240554
# [500]	training's auc: 0.844707	training's binary_logloss: 0.216921	valid_1's auc: 0.776863	valid_1's binary_logloss: 0.240233
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.844707	training's binary_logloss: 0.216921	valid_1's auc: 0.776863	valid_1's binary_logloss: 0.240233
# |  11       |  0.7769   |  0.6872   |  479.6    |  10.23    |  24.87    |  6.99     |  60.1     |  0.8071   |  5.777    |  0.7787   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781101	training's binary_logloss: 0.24234	valid_1's auc: 0.760147	valid_1's binary_logloss: 0.24728
# [200]	training's auc: 0.803437	training's binary_logloss: 0.2327	valid_1's auc: 0.770345	valid_1's binary_logloss: 0.24258
# [300]	training's auc: 0.82016	training's binary_logloss: 0.22623	valid_1's auc: 0.77462	valid_1's binary_logloss: 0.241016
# [400]	training's auc: 0.834068	training's binary_logloss: 0.220907	valid_1's auc: 0.776459	valid_1's binary_logloss: 0.24032
# [500]	training's auc: 0.846267	training's binary_logloss: 0.21622	valid_1's auc: 0.777578	valid_1's binary_logloss: 0.239929
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.846267	training's binary_logloss: 0.21622	valid_1's auc: 0.777578	valid_1's binary_logloss: 0.239929
# |  12       |  0.7776   |  0.6874   |  479.6    |  15.62    |  15.73    |  46.02    |  60.62    |  0.6881   |  2.142    |  0.9413   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.777962	training's binary_logloss: 0.242621	valid_1's auc: 0.758094	valid_1's binary_logloss: 0.247394
# [200]	training's auc: 0.801477	training's binary_logloss: 0.23316	valid_1's auc: 0.769493	valid_1's binary_logloss: 0.242854
# [300]	training's auc: 0.818268	training's binary_logloss: 0.226772	valid_1's auc: 0.77417	valid_1's binary_logloss: 0.241209
# [400]	training's auc: 0.831748	training's binary_logloss: 0.221626	valid_1's auc: 0.776221	valid_1's binary_logloss: 0.240519
# [500]	training's auc: 0.843541	training's binary_logloss: 0.217126	valid_1's auc: 0.776981	valid_1's binary_logloss: 0.240284
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.843541	training's binary_logloss: 0.217126	valid_1's auc: 0.776981	valid_1's binary_logloss: 0.240284
# |  13       |  0.777    |  0.9558   |  493.2    |  15.27    |  18.25    |  40.87    |  55.51    |  0.4371   |  1.348    |  0.9353   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.770294	training's binary_logloss: 0.245377	valid_1's auc: 0.756901	valid_1's binary_logloss: 0.248285
# [200]	training's auc: 0.790013	training's binary_logloss: 0.237373	valid_1's auc: 0.767528	valid_1's binary_logloss: 0.243599
# [300]	training's auc: 0.803834	training's binary_logloss: 0.232274	valid_1's auc: 0.772592	valid_1's binary_logloss: 0.241778
# [400]	training's auc: 0.814922	training's binary_logloss: 0.228236	valid_1's auc: 0.775084	valid_1's binary_logloss: 0.240883
# [500]	training's auc: 0.824481	training's binary_logloss: 0.224852	valid_1's auc: 0.776298	valid_1's binary_logloss: 0.240454
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.824481	training's binary_logloss: 0.224852	valid_1's auc: 0.776298	valid_1's binary_logloss: 0.240454
# |  14       |  0.7763   |  0.6557   |  489.9    |  10.31    |  17.82    |  1.049    |  37.8     |  1.685    |  1.641    |  0.5974   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.779578	training's binary_logloss: 0.243502	valid_1's auc: 0.759968	valid_1's binary_logloss: 0.247815
# [200]	training's auc: 0.799832	training's binary_logloss: 0.234257	valid_1's auc: 0.769824	valid_1's binary_logloss: 0.242909
# [300]	training's auc: 0.815048	training's binary_logloss: 0.228301	valid_1's auc: 0.773989	valid_1's binary_logloss: 0.241274
# [400]	training's auc: 0.82824	training's binary_logloss: 0.223315	valid_1's auc: 0.776412	valid_1's binary_logloss: 0.240403
# [500]	training's auc: 0.839625	training's binary_logloss: 0.218993	valid_1's auc: 0.777459	valid_1's binary_logloss: 0.240016
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.839625	training's binary_logloss: 0.218993	valid_1's auc: 0.777459	valid_1's binary_logloss: 0.240016
# |  15       |  0.7775   |  0.5838   |  478.1    |  15.33    |  16.94    |  43.66    |  58.1     |  1.873    |  6.926    |  0.821    |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.780136	training's binary_logloss: 0.24262	valid_1's auc: 0.758714	valid_1's binary_logloss: 0.247505
# [200]	training's auc: 0.802917	training's binary_logloss: 0.233017	valid_1's auc: 0.769682	valid_1's binary_logloss: 0.242809
# [300]	training's auc: 0.819451	training's binary_logloss: 0.22659	valid_1's auc: 0.773752	valid_1's binary_logloss: 0.241334
# [400]	training's auc: 0.833328	training's binary_logloss: 0.221277	valid_1's auc: 0.776042	valid_1's binary_logloss: 0.240514
# [500]	training's auc: 0.845115	training's binary_logloss: 0.216682	valid_1's auc: 0.777182	valid_1's binary_logloss: 0.240115
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.845115	training's binary_logloss: 0.216682	valid_1's auc: 0.777182	valid_1's binary_logloss: 0.240115
# |  16       |  0.7772   |  0.879    |  487.3    |  13.74    |  22.79    |  47.05    |  63.32    |  1.131    |  9.356    |  0.8718   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.778553	training's binary_logloss: 0.243214	valid_1's auc: 0.759151	valid_1's binary_logloss: 0.247681
# [200]	training's auc: 0.800338	training's binary_logloss: 0.233945	valid_1's auc: 0.769981	valid_1's binary_logloss: 0.242867
# [300]	training's auc: 0.816293	training's binary_logloss: 0.227839	valid_1's auc: 0.774466	valid_1's binary_logloss: 0.241216
# [400]	training's auc: 0.829769	training's binary_logloss: 0.222764	valid_1's auc: 0.77684	valid_1's binary_logloss: 0.240344
# [500]	training's auc: 0.84098	training's binary_logloss: 0.218495	valid_1's auc: 0.778048	valid_1's binary_logloss: 0.239917
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.84098	training's binary_logloss: 0.218495	valid_1's auc: 0.778048	valid_1's binary_logloss: 0.239917
# |  17       |  0.778    |  0.7437   |  494.7    |  14.27    |  25.78    |  2.691    |  57.97    |  2.47     |  9.797    |  0.5824   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.779663	training's binary_logloss: 0.243089	valid_1's auc: 0.759328	valid_1's binary_logloss: 0.247772
# [200]	training's auc: 0.800579	training's binary_logloss: 0.233916	valid_1's auc: 0.769592	valid_1's binary_logloss: 0.242989
# [300]	training's auc: 0.81581	training's binary_logloss: 0.227961	valid_1's auc: 0.773922	valid_1's binary_logloss: 0.24136
# [400]	training's auc: 0.828448	training's binary_logloss: 0.223086	valid_1's auc: 0.776537	valid_1's binary_logloss: 0.240452
# [500]	training's auc: 0.839689	training's binary_logloss: 0.218765	valid_1's auc: 0.777791	valid_1's binary_logloss: 0.239969
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.839689	training's binary_logloss: 0.218765	valid_1's auc: 0.777791	valid_1's binary_logloss: 0.239969
# |  18       |  0.7778   |  0.6975   |  467.5    |  10.23    |  22.57    |  3.607    |  62.53    |  5.255    |  8.662    |  0.7036   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.780078	training's binary_logloss: 0.243329	valid_1's auc: 0.760092	valid_1's binary_logloss: 0.247818
# [200]	training's auc: 0.800394	training's binary_logloss: 0.234107	valid_1's auc: 0.770018	valid_1's binary_logloss: 0.242928
# [300]	training's auc: 0.815651	training's binary_logloss: 0.228138	valid_1's auc: 0.774223	valid_1's binary_logloss: 0.241298
# [400]	training's auc: 0.828422	training's binary_logloss: 0.223197	valid_1's auc: 0.776583	valid_1's binary_logloss: 0.240427
# [500]	training's auc: 0.83973	training's binary_logloss: 0.218904	valid_1's auc: 0.777942	valid_1's binary_logloss: 0.23993
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.83973	training's binary_logloss: 0.218904	valid_1's auc: 0.777942	valid_1's binary_logloss: 0.23993
# |  19       |  0.7779   |  0.5437   |  488.4    |  10.29    |  45.29    |  1.819    |  62.43    |  3.419    |  9.019    |  0.6595   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.775537	training's binary_logloss: 0.244805	valid_1's auc: 0.756923	valid_1's binary_logloss: 0.248491
# [200]	training's auc: 0.794163	training's binary_logloss: 0.236787	valid_1's auc: 0.766883	valid_1's binary_logloss: 0.243937
# [300]	training's auc: 0.806155	training's binary_logloss: 0.232062	valid_1's auc: 0.771886	valid_1's binary_logloss: 0.242106
# [400]	training's auc: 0.814888	training's binary_logloss: 0.228602	valid_1's auc: 0.774125	valid_1's binary_logloss: 0.241263
# [500]	training's auc: 0.822414	training's binary_logloss: 0.225643	valid_1's auc: 0.775568	valid_1's binary_logloss: 0.240776
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.822414	training's binary_logloss: 0.225643	valid_1's auc: 0.775568	valid_1's binary_logloss: 0.240776
# |  20       |  0.7756   |  0.7745   |  488.7    |  6.037    |  34.42    |  5.833    |  60.81    |  7.308    |  0.9877   |  0.5466   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.779669	training's binary_logloss: 0.243236	valid_1's auc: 0.759311	valid_1's binary_logloss: 0.247666
# [200]	training's auc: 0.799996	training's binary_logloss: 0.234339	valid_1's auc: 0.769514	valid_1's binary_logloss: 0.243003
# [300]	training's auc: 0.813046	training's binary_logloss: 0.229103	valid_1's auc: 0.773553	valid_1's binary_logloss: 0.241444
# [400]	training's auc: 0.823131	training's binary_logloss: 0.22518	valid_1's auc: 0.775455	valid_1's binary_logloss: 0.240737
# [500]	training's auc: 0.831569	training's binary_logloss: 0.221873	valid_1's auc: 0.77665	valid_1's binary_logloss: 0.240306
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.831569	training's binary_logloss: 0.221873	valid_1's auc: 0.77665	valid_1's binary_logloss: 0.240306
# |  21       |  0.7767   |  0.7307   |  497.6    |  7.704    |  43.93    |  49.29    |  62.3     |  2.761    |  6.593    |  0.7549   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781639	training's binary_logloss: 0.242137	valid_1's auc: 0.758526	valid_1's binary_logloss: 0.247503
# [200]	training's auc: 0.805126	training's binary_logloss: 0.23263	valid_1's auc: 0.768976	valid_1's binary_logloss: 0.243107
# [300]	training's auc: 0.820635	training's binary_logloss: 0.22657	valid_1's auc: 0.773201	valid_1's binary_logloss: 0.241573
# [400]	training's auc: 0.832226	training's binary_logloss: 0.222158	valid_1's auc: 0.775071	valid_1's binary_logloss: 0.240913
# [500]	training's auc: 0.84362	training's binary_logloss: 0.217876	valid_1's auc: 0.776496	valid_1's binary_logloss: 0.24046
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.84362	training's binary_logloss: 0.217876	valid_1's auc: 0.776496	valid_1's binary_logloss: 0.24046
# |  22       |  0.7765   |  0.9702   |  490.2    |  6.676    |  130.6    |  1.011    |  62.38    |  1.419    |  0.3271   |  0.5556   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.776863	training's binary_logloss: 0.244754	valid_1's auc: 0.758584	valid_1's binary_logloss: 0.248357
# [200]	training's auc: 0.79531	training's binary_logloss: 0.236514	valid_1's auc: 0.767616	valid_1's binary_logloss: 0.243758
# [300]	training's auc: 0.807759	training's binary_logloss: 0.231616	valid_1's auc: 0.772192	valid_1's binary_logloss: 0.241993
# [400]	training's auc: 0.816863	training's binary_logloss: 0.227928	valid_1's auc: 0.774506	valid_1's binary_logloss: 0.241086
# [500]	training's auc: 0.824982	training's binary_logloss: 0.224791	valid_1's auc: 0.775856	valid_1's binary_logloss: 0.240589
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.824982	training's binary_logloss: 0.224791	valid_1's auc: 0.775856	valid_1's binary_logloss: 0.240589
# |  23       |  0.7759   |  0.594    |  493.5    |  6.165    |  26.6     |  1.477    |  60.15    |  4.686    |  2.352    |  0.9888   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.780768	training's binary_logloss: 0.242193	valid_1's auc: 0.75918	valid_1's binary_logloss: 0.247238
# [200]	training's auc: 0.803494	training's binary_logloss: 0.23266	valid_1's auc: 0.769601	valid_1's binary_logloss: 0.242822
# [300]	training's auc: 0.818631	training's binary_logloss: 0.226701	valid_1's auc: 0.772958	valid_1's binary_logloss: 0.241548
# [400]	training's auc: 0.830276	training's binary_logloss: 0.22223	valid_1's auc: 0.775298	valid_1's binary_logloss: 0.240774
# [500]	training's auc: 0.840332	training's binary_logloss: 0.218401	valid_1's auc: 0.776645	valid_1's binary_logloss: 0.240327
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.840332	training's binary_logloss: 0.218401	valid_1's auc: 0.776645	valid_1's binary_logloss: 0.240327
# |  24       |  0.7766   |  0.9335   |  495.5    |  9.276    |  21.97    |  43.59    |  63.13    |  0.3813   |  4.526    |  0.5504   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.763464	training's binary_logloss: 0.24718	valid_1's auc: 0.75396	valid_1's binary_logloss: 0.249003
# [200]	training's auc: 0.781626	training's binary_logloss: 0.239976	valid_1's auc: 0.765987	valid_1's binary_logloss: 0.244136
# [300]	training's auc: 0.7932	training's binary_logloss: 0.235751	valid_1's auc: 0.771646	valid_1's binary_logloss: 0.242137
# [400]	training's auc: 0.802154	training's binary_logloss: 0.232543	valid_1's auc: 0.77476	valid_1's binary_logloss: 0.241049
# [500]	training's auc: 0.809313	training's binary_logloss: 0.230017	valid_1's auc: 0.775998	valid_1's binary_logloss: 0.240593
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.809313	training's binary_logloss: 0.230017	valid_1's auc: 0.775998	valid_1's binary_logloss: 0.240593
# |  25       |  0.776    |  0.861    |  492.5    |  12.7     |  15.12    |  1.937    |  27.72    |  1.034    |  8.386    |  0.6302   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.77895	training's binary_logloss: 0.24348	valid_1's auc: 0.759417	valid_1's binary_logloss: 0.247784
# [200]	training's auc: 0.798731	training's binary_logloss: 0.234628	valid_1's auc: 0.76931	valid_1's binary_logloss: 0.243105
# [300]	training's auc: 0.813704	training's binary_logloss: 0.228824	valid_1's auc: 0.773618	valid_1's binary_logloss: 0.241488
# [400]	training's auc: 0.826403	training's binary_logloss: 0.223961	valid_1's auc: 0.776205	valid_1's binary_logloss: 0.240558
# [500]	training's auc: 0.837626	training's binary_logloss: 0.219667	valid_1's auc: 0.777397	valid_1's binary_logloss: 0.240092
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.837626	training's binary_logloss: 0.219667	valid_1's auc: 0.777397	valid_1's binary_logloss: 0.240092
# |  26       |  0.7774   |  0.6638   |  478.1    |  14.14    |  19.42    |  47.59    |  62.23    |  7.326    |  5.152    |  0.8538   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.781128	training's binary_logloss: 0.242371	valid_1's auc: 0.7596	valid_1's binary_logloss: 0.247334
# [200]	training's auc: 0.803663	training's binary_logloss: 0.232679	valid_1's auc: 0.769873	valid_1's binary_logloss: 0.242723
# [300]	training's auc: 0.820325	training's binary_logloss: 0.226208	valid_1's auc: 0.773856	valid_1's binary_logloss: 0.241241
# [400]	training's auc: 0.834453	training's binary_logloss: 0.220801	valid_1's auc: 0.776126	valid_1's binary_logloss: 0.240458
# [500]	training's auc: 0.846246	training's binary_logloss: 0.216217	valid_1's auc: 0.777123	valid_1's binary_logloss: 0.240081
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.846246	training's binary_logloss: 0.216217	valid_1's auc: 0.777123	valid_1's binary_logloss: 0.240081
# |  27       |  0.7771   |  0.7899   |  451.0    |  14.17    |  16.47    |  48.3     |  62.66    |  0.8003   |  5.522    |  0.5739   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.778882	training's binary_logloss: 0.243874	valid_1's auc: 0.759313	valid_1's binary_logloss: 0.248008
# [200]	training's auc: 0.798016	training's binary_logloss: 0.23524	valid_1's auc: 0.768777	valid_1's binary_logloss: 0.243316
# [300]	training's auc: 0.811013	training's binary_logloss: 0.230093	valid_1's auc: 0.773045	valid_1's binary_logloss: 0.241679
# [400]	training's auc: 0.820855	training's binary_logloss: 0.226176	valid_1's auc: 0.775129	valid_1's binary_logloss: 0.240876
# [500]	training's auc: 0.829652	training's binary_logloss: 0.222776	valid_1's auc: 0.776519	valid_1's binary_logloss: 0.240353
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.829652	training's binary_logloss: 0.222776	valid_1's auc: 0.776519	valid_1's binary_logloss: 0.240353
# |  28       |  0.7765   |  0.6147   |  485.7    |  7.26     |  19.26    |  5.714    |  60.35    |  2.702    |  9.9      |  0.6904   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.77289	training's binary_logloss: 0.24498	valid_1's auc: 0.757677	valid_1's binary_logloss: 0.248164
# [200]	training's auc: 0.792195	training's binary_logloss: 0.236659	valid_1's auc: 0.768396	valid_1's binary_logloss: 0.2433
# [300]	training's auc: 0.805419	training's binary_logloss: 0.231583	valid_1's auc: 0.772935	valid_1's binary_logloss: 0.241604
# [400]	training's auc: 0.816337	training's binary_logloss: 0.22748	valid_1's auc: 0.775689	valid_1's binary_logloss: 0.240637
# [500]	training's auc: 0.825461	training's binary_logloss: 0.224103	valid_1's auc: 0.776814	valid_1's binary_logloss: 0.240223
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.825461	training's binary_logloss: 0.224103	valid_1's auc: 0.776814	valid_1's binary_logloss: 0.240223
# |  29       |  0.7768   |  0.7049   |  484.8    |  10.56    |  13.1     |  48.91    |  43.8     |  0.5117   |  9.967    |  0.7057   |
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.770998	training's binary_logloss: 0.245158	valid_1's auc: 0.757085	valid_1's binary_logloss: 0.248275
# [200]	training's auc: 0.791679	training's binary_logloss: 0.23683	valid_1's auc: 0.767821	valid_1's binary_logloss: 0.243534
# [300]	training's auc: 0.806403	training's binary_logloss: 0.231488	valid_1's auc: 0.772479	valid_1's binary_logloss: 0.241821
# [400]	training's auc: 0.818757	training's binary_logloss: 0.227132	valid_1's auc: 0.77485	valid_1's binary_logloss: 0.240942
# [500]	training's auc: 0.830021	training's binary_logloss: 0.223328	valid_1's auc: 0.77589	valid_1's binary_logloss: 0.2406
# Did not meet early stopping. Best iteration is:
# [500]	training's auc: 0.830021	training's binary_logloss: 0.223328	valid_1's auc: 0.77589	valid_1's binary_logloss: 0.2406
# |  30       |  0.7759   |  0.6788   |  499.1    |  9.791    |  12.04    |  1.209    |  37.5     |  1.511    |  0.2041   |  0.5108   |
# =====================================================================================================================================

# %% [markdown]
# ##### Iteration 수행 결과 출력

# %%
# BayesianOptimization객체의 res는 iteration 수행 시마다 모든 함수 반환결과와 그때의 파라미터 결과값을 가지고 있음. 
lgbBO.res
# Out:
# [{'params': {'colsample_bytree': 0.7744067519636624,
#    'max_bin': 360.44278952248555,
#    'max_depth': 12.027633760716439,
#    'min_child_samples': 113.52780476941041,
#    'min_child_weight': 21.75908516760633,
#    'num_leaves': 49.835764522666246,
#    'reg_alpha': 21.884984691022,
#    'reg_lambda': 8.917838234820016,
#    'subsamples': 0.9818313802505146},
#   'target': 0.7754739702428558},
#  {'params': {'colsample_bytree': 0.6917207594128889,
#    'max_bin': 397.94526866050563,
#    'max_depth': 11.288949197529044,
#    'min_child_samples': 117.92846660784714,
#    'min_child_weight': 46.35423527634039,
#    'num_leaves': 26.841442327915477,
#    'reg_alpha': 4.36559369208002,
#    'reg_lambda': 0.20316375600581688,
#    'subsamples': 0.916309922773969},
#   'target': 0.7753573432834208},
#  {'params': {'colsample_bytree': 0.8890783754749252,
#    'max_bin': 436.30595264094137,
#    'max_depth': 15.78618342232764,
#    'min_child_samples': 161.8401272011775,
#    'min_child_weight': 23.61248875039366,
#    'num_leaves': 55.22116705145822,
#    'reg_alpha': 5.922538549187972,
#    'reg_lambda': 6.3995702922539115,
#    'subsamples': 0.5716766437045232},
#   'target': 0.7773320021744632},
#  {'params': {'colsample_bytree': 0.972334458524792,
#    'max_bin': 265.70567765753515,
#    'max_depth': 10.146619399905235,
#    'min_child_samples': 60.265566299879126,
#    'min_child_weight': 38.93745078227661,
#    'num_leaves': 42.24601328866194,
#    'reg_alpha': 28.426013103943742,
#    'reg_lambda': 0.18887921456311507,
#    'subsamples': 0.8088177485379385},
#   'target': 0.7749940765618106},
#  {'params': {'colsample_bytree': 0.8060478613612108,
#    'max_bin': 312.2976584686309,
#    'max_depth': 15.437480785146242,
#    'min_child_samples': 139.54585682966186,
#    'min_child_weight': 18.615887128115514,
#    'num_leaves': 41.481278151973655,
#    'reg_alpha': 34.88458348440397,
#    'reg_lambda': 0.6031944908210691,
#    'subsamples': 0.8333833577228338},
#   'target': 0.7741980660329925},
#  {'params': {'colsample_bytree': 0.8538298637688885,
#    'max_bin': 499.18172097104025,
#    'max_depth': 7.1187205183646585,
#    'min_child_samples': 10.40382501514027,
#    'min_child_weight': 37.64143876594502,
#    'num_leaves': 46.751076731952274,
#    'reg_alpha': 34.54679765680322,
#    'reg_lambda': 7.535496823229152,
#    'subsamples': 0.7467532758879181},
#   'target': 0.7743139273609485},
#  {'params': {'colsample_bytree': 0.9750941359511892,
#    'max_bin': 12.501359452451002,
#    'max_depth': 15.865587065065188,
#    'min_child_samples': 199.06043810748636,
#    'min_child_weight': 43.32982582556308,
#    'num_leaves': 53.78170583679077,
#    'reg_alpha': 14.984214461767769,
#    'reg_lambda': 9.60963231580962,
#    'subsamples': 0.7368099967377815},
#   'target': 0.7720062711953142},
#  {'params': {'colsample_bytree': 0.5606964411191951,
#    'max_bin': 497.7454412199526,
#    'max_depth': 7.087272483457448,
#    'min_child_samples': 199.5175802035777,
#    'min_child_weight': 48.53382598339578,
#    'num_leaves': 46.57200227776936,
#    'reg_alpha': 8.795600579406749,
#    'reg_lambda': 5.27619358756324,
#    'subsamples': 0.8411371145522544},
#   'target': 0.7756544353008543},
#  {'params': {'colsample_bytree': 0.9722063900233824,
#    'max_bin': 497.82308500508594,
#    'max_depth': 15.758325685837493,
#    'min_child_samples': 197.60491797740553,
#    'min_child_weight': 4.999554027770358,
#    'num_leaves': 32.35325045820552,
#    'reg_alpha': 43.15240531167431,
#    'reg_lambda': 0.16547147713489843,
#    'subsamples': 0.6482851764642698},
#   'target': 0.7727560197921964},
#  {'params': {'colsample_bytree': 0.5342232406645204,
#    'max_bin': 489.86665132276073,
#    'max_depth': 8.997688603000276,
#    'min_child_samples': 10.210966478486121,
#    'min_child_weight': 39.73455999523621,
#    'num_leaves': 36.507079883778296,
#    'reg_alpha': 1.808669646029281,
#    'reg_lambda': 5.03958878713407,
#    'subsamples': 0.5382652171575891},
#   'target': 0.7764914515903136},
#  {'params': {'colsample_bytree': 0.6871924599882824,
#    'max_bin': 479.6386373823657,
#    'max_depth': 10.234811669618706,
#    'min_child_samples': 24.871920387237736,
#    'min_child_weight': 6.990018287895288,
#    'num_leaves': 60.103948656421274,
#    'reg_alpha': 0.8071247513752541,
#    'reg_lambda': 5.776756371548493,
#    'subsamples': 0.7786645674657318},
#   'target': 0.7768626430742653},
#  {'params': {'colsample_bytree': 0.687432080723539,
#    'max_bin': 479.5790809130459,
#    'max_depth': 15.624247892861597,
#    'min_child_samples': 15.727227480527613,
#    'min_child_weight': 46.015612690004126,
#    'num_leaves': 60.62355316972579,
#    'reg_alpha': 0.6880799034091644,
#    'reg_lambda': 2.141966980555839,
#    'subsamples': 0.9412841359789756},
#   'target': 0.777577672983937},
#  {'params': {'colsample_bytree': 0.955778913998498,
#    'max_bin': 493.24533086499315,
#    'max_depth': 15.267484348764935,
#    'min_child_samples': 18.245751562382765,
#    'min_child_weight': 40.870752907958405,
#    'num_leaves': 55.505857378740615,
#    'reg_alpha': 0.43710361190113756,
#    'reg_lambda': 1.3483530217402222,
#    'subsamples': 0.9352585984365811},
#   'target': 0.7769813334264206},
#  {'params': {'colsample_bytree': 0.6557051331388017,
#    'max_bin': 489.8934216857914,
#    'max_depth': 10.31143629269451,
#    'min_child_samples': 17.81696518957149,
#    'min_child_weight': 1.0494732128777182,
#    'num_leaves': 37.80201876050929,
#    'reg_alpha': 1.6854128477794645,
#    'reg_lambda': 1.6410327033509082,
#    'subsamples': 0.5973767065010218},
#   'target': 0.7762975625662807},
#  {'params': {'colsample_bytree': 0.5837978592082946,
#    'max_bin': 478.06947661959055,
#    'max_depth': 15.331072812311916,
#    'min_child_samples': 16.944932284758288,
#    'min_child_weight': 43.66259945159295,
#    'num_leaves': 58.10308105931011,
#    'reg_alpha': 1.8732768087453089,
#    'reg_lambda': 6.925846042954574,
#    'subsamples': 0.8210062735198591},
#   'target': 0.7774589032094291},
#  {'params': {'colsample_bytree': 0.878984166735569,
#    'max_bin': 487.319455209816,
#    'max_depth': 13.74347971689194,
#    'min_child_samples': 22.793854301098456,
#    'min_child_weight': 47.051313468761144,
#    'num_leaves': 63.32449765350978,
#    'reg_alpha': 1.131005525995249,
#    'reg_lambda': 9.356034325036058,
#    'subsamples': 0.8717664011361355},
#   'target': 0.7771821464911522},
#  {'params': {'colsample_bytree': 0.7436762853652641,
#    'max_bin': 494.6519941194128,
#    'max_depth': 14.273550154831288,
#    'min_child_samples': 25.784295891426886,
#    'min_child_weight': 2.6913774511864754,
#    'num_leaves': 57.965834800533756,
#    'reg_alpha': 2.4699153309230764,
#    'reg_lambda': 9.797178761741076,
#    'subsamples': 0.5823503102854222},
#   'target': 0.7780482186540827},
#  {'params': {'colsample_bytree': 0.6974622852743844,
#    'max_bin': 467.4711221671223,
#    'max_depth': 10.230484948219582,
#    'min_child_samples': 22.574247463399168,
#    'min_child_weight': 3.60739558479408,
#    'num_leaves': 62.53317443276672,
#    'reg_alpha': 5.255418817283818,
#    'reg_lambda': 8.661520568805088,
#    'subsamples': 0.7035580471149167},
#   'target': 0.7777908139862375},
#  {'params': {'colsample_bytree': 0.5437407286308563,
#    'max_bin': 488.3548304818276,
#    'max_depth': 10.285653018830278,
#    'min_child_samples': 45.29162859948177,
#    'min_child_weight': 1.8189456648868672,
#    'num_leaves': 62.43189084803863,
#    'reg_alpha': 3.4190610024000705,
#    'reg_lambda': 9.01873010403026,
#    'subsamples': 0.6595375490385381},
#   'target': 0.7779424074306232},
#  {'params': {'colsample_bytree': 0.7745130300822609,
#    'max_bin': 488.68846826819686,
#    'max_depth': 6.037461418571719,
#    'min_child_samples': 34.4169937605701,
#    'min_child_weight': 5.833403026794266,
#    'num_leaves': 60.80651810352303,
#    'reg_alpha': 7.307667210692115,
#    'reg_lambda': 0.9877307504431427,
#    'subsamples': 0.5465779714003538},
#   'target': 0.7755680269581322},
#  {'params': {'colsample_bytree': 0.7306833224982413,
#    'max_bin': 497.6429483962119,
#    'max_depth': 7.703617399780626,
#    'min_child_samples': 43.933314820516514,
#    'min_child_weight': 49.292873668988236,
#    'num_leaves': 62.29738922363282,
#    'reg_alpha': 2.760930627922642,
#    'reg_lambda': 6.592754587746761,
#    'subsamples': 0.7548714507500771},
#   'target': 0.7766501692197265},
#  {'params': {'colsample_bytree': 0.9702051409369551,
#    'max_bin': 490.2468911528458,
#    'max_depth': 6.675646963122917,
#    'min_child_samples': 130.59760265574238,
#    'min_child_weight': 1.0107380385879603,
#    'num_leaves': 62.37894582515848,
#    'reg_alpha': 1.419040898790039,
#    'reg_lambda': 0.32710686177754544,
#    'subsamples': 0.5555631966642643},
#   'target': 0.7764958579424354},
#  {'params': {'colsample_bytree': 0.5939730226596387,
#    'max_bin': 493.4939994485024,
#    'max_depth': 6.165368640539341,
#    'min_child_samples': 26.597526415005788,
#    'min_child_weight': 1.4766355056497291,
#    'num_leaves': 60.14844685457922,
#    'reg_alpha': 4.686393994145287,
#    'reg_lambda': 2.3517785307956647,
#    'subsamples': 0.988798782614232},
#   'target': 0.7758560235277473},
#  {'params': {'colsample_bytree': 0.9335178880792802,
#    'max_bin': 495.4705853959828,
#    'max_depth': 9.275577008280285,
#    'min_child_samples': 21.97422388511532,
#    'min_child_weight': 43.58541175677125,
#    'num_leaves': 63.128263229486635,
#    'reg_alpha': 0.3813229629049955,
#    'reg_lambda': 4.526261020784162,
#    'subsamples': 0.5503847974222735},
#   'target': 0.7766452895103834},
#  {'params': {'colsample_bytree': 0.8609688575892369,
#    'max_bin': 492.5130460857743,
#    'max_depth': 12.704233001329275,
#    'min_child_samples': 15.12064118686286,
#    'min_child_weight': 1.937108403750006,
#    'num_leaves': 27.717729763522392,
#    'reg_alpha': 1.0344979663831602,
#    'reg_lambda': 8.386183291300387,
#    'subsamples': 0.6301564507620973},
#   'target': 0.7759978146653764},
#  {'params': {'colsample_bytree': 0.6637581182039965,
#    'max_bin': 478.1043158687786,
#    'max_depth': 14.143838192928582,
#    'min_child_samples': 19.416823523968596,
#    'min_child_weight': 47.588246099984744,
#    'num_leaves': 62.23191279604004,
#    'reg_alpha': 7.325958014492767,
#    'reg_lambda': 5.151845619559748,
#    'subsamples': 0.8538381398189729},
#   'target': 0.7773965376012826},
#  {'params': {'colsample_bytree': 0.7899081844055998,
#    'max_bin': 451.0489642863229,
#    'max_depth': 14.166461630530417,
#    'min_child_samples': 16.4694838865052,
#    'min_child_weight': 48.29924042617962,
#    'num_leaves': 62.66005194793132,
#    'reg_alpha': 0.8003075082970005,
#    'reg_lambda': 5.521570856635001,
#    'subsamples': 0.5739446148147153},
#   'target': 0.7771233405928487},
#  {'params': {'colsample_bytree': 0.6146526165857328,
#    'max_bin': 485.66445905580105,
#    'max_depth': 7.259950461855689,
#    'min_child_samples': 19.264095092455467,
#    'min_child_weight': 5.714188025170126,
#    'num_leaves': 60.354986335797236,
#    'reg_alpha': 2.7024242768304942,
#    'reg_lambda': 9.90021113905228,
#    'subsamples': 0.6903840702052592},
#   'target': 0.7765192494137196},
#  {'params': {'colsample_bytree': 0.7048968334628858,
#    'max_bin': 484.82472602615434,
#    'max_depth': 10.55974479883751,
#    'min_child_samples': 13.095052894611987,
#    'min_child_weight': 48.907808701184535,
#    'num_leaves': 43.80076300813039,
#    'reg_alpha': 0.5116783103676071,
#    'reg_lambda': 9.966798515319228,
#    'subsamples': 0.7057371801704698},
#   'target': 0.7768137856198469},
#  {'params': {'colsample_bytree': 0.6787973056586718,
#    'max_bin': 499.12451398147346,
#    'max_depth': 9.791393974727306,
#    'min_child_samples': 12.04307994116352,
#    'min_child_weight': 1.2092535299513751,
#    'num_leaves': 37.50084251381196,
#    'reg_alpha': 1.511103192515003,
#    'reg_lambda': 0.2041043723043457,
#    'subsamples': 0.5107804152361152},
#   'target': 0.775890440410018}]

# %% [markdown]
# ##### Iteration 결과 Dictionary에서 최대 target값을 가지는 index 추출하고 그때의 parameter 값을 추출.

# %%
# dictionary에 있는 target값을 모두 추출
target_list = []
for result in lgbBO.res:
  target = result['target']
  target_list.append(target)
print(target_list)

# 가장 큰 target값을 가지는 순번(index)를 추출
print('maximum target index :', np.argmax(target_list))
# Out:
# [0.7754739702428558, 0.7753573432834208, 0.7773320021744632, 0.7749940765618106, 0.7741980660329925, 0.7743139273609485, 0.7720062711953142, 0.7756544353008543, 0.7727560197921964, 0.7764914515903136, 0.7768626430742653, 0.777577672983937, 0.7769813334264206, 0.7762975625662807, 0.7774589032094291, 0.7771821464911522, 0.7780482186540827, 0.7777908139862375, 0.7779424074306232, 0.7755680269581322, 0.7766501692197265, 0.7764958579424354, 0.7758560235277473, 0.7766452895103834, 0.7759978146653764, 0.7773965376012826, 0.7771233405928487, 0.7765192494137196, 0.7768137856198469, 0.775890440410018]
# maximum target index : 16

# %%
np.array(target_list)
# Out:
# array([0.77547397, 0.77535734, 0.777332  , 0.77499408, 0.77419807,
#        0.77431393, 0.77200627, 0.77565444, 0.77275602, 0.77649145,
#        0.77686264, 0.77757767, 0.77698133, 0.77629756, 0.7774589 ,
#        0.77718215, 0.77804822, 0.77779081, 0.77794241, 0.77556803,
#        0.77665017, 0.77649586, 0.77585602, 0.77664529, 0.77599781,
#        0.77739654, 0.77712334, 0.77651925, 0.77681379, 0.77589044])

# %%
# 가장 큰 target값을 가지는 index값을 기준으로 res에서 해당 parameter 추출. 
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7780482186540827, 'params': {'colsample_bytree': 0.7436762853652641, 'max_bin': 494.6519941194128, 'max_depth': 14.273550154831288, 'min_child_samples': 25.784295891426886, 'min_child_weight': 2.6913774511864754, 'num_leaves': 57.965834800533756, 'reg_alpha': 2.4699153309230764, 'reg_lambda': 9.797178761741076, 'subsamples': 0.5823503102854222}}

# %% [markdown]
# ##### 최적화된 하이퍼 파라미터를 기반으로 재 테스트
# {'target': 0.7780482186540827, 'params': {'colsample_bytree': 0.7436762853652641, 'max_bin': 494.6519941194128, 'max_depth': 14.273550154831288, 'min_child_samples': 25.784295891426886, 'min_child_weight': 2.6913774511864754, 'num_leaves': 57.965834800533756, 'reg_alpha': 2.4699153309230764, 'reg_lambda': 9.797178761741076, 'subsample': 0.5823503102854222}}

# %%
def train_apps_all(apps_all_train):
  """
  위에서 나온 최적 파라미터 기반으로 다시 테스트 
  """
  ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
  target_app = apps_all_train['TARGET']

  train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
  print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)

  clf = LGBMClassifier(
                      nthread=4,
                      n_estimators=1000,
                      learning_rate=0.02,
                      max_depth = 14,
                      num_leaves=58,
                      colsample_bytree=0.743,
                      subsample=0.582,
                      max_bin=495,
                      reg_alpha=2.469,
                      reg_lambda=9.797,
                      min_child_weight=3,
                      min_child_samples=26,
                      silent=-1,
                      verbose=-1)
  clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, early_stopping_rounds= 100)
      
  return clf

# %%
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)
# train shape: (215257, 174) valid shape: (92254, 174)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.778505	training's binary_logloss: 0.243199	valid_1's auc: 0.759267	valid_1's binary_logloss: 0.247651
# [200]	training's auc: 0.800126	training's binary_logloss: 0.233974	valid_1's auc: 0.769733	valid_1's binary_logloss: 0.242908
# [300]	training's auc: 0.816202	training's binary_logloss: 0.227823	valid_1's auc: 0.77418	valid_1's binary_logloss: 0.241285
# [400]	training's auc: 0.829678	training's binary_logloss: 0.222716	valid_1's auc: 0.77678	valid_1's binary_logloss: 0.240349
# [500]	training's auc: 0.840759	training's binary_logloss: 0.218456	valid_1's auc: 0.777721	valid_1's binary_logloss: 0.239991
# [600]	training's auc: 0.850681	training's binary_logloss: 0.214684	valid_1's auc: 0.778337	valid_1's binary_logloss: 0.239793
# [700]	training's auc: 0.859847	training's binary_logloss: 0.211068	valid_1's auc: 0.778743	valid_1's binary_logloss: 0.239653
# [800]	training's auc: 0.868326	training's binary_logloss: 0.207743	valid_1's auc: 0.779021	valid_1's binary_logloss: 0.239558
# [900]	training's auc: 0.875939	training's binary_logloss: 0.204616	valid_1's auc: 0.779104	valid_1's binary_logloss: 0.239528
# [1000]	training's auc: 0.883068	training's binary_logloss: 0.201588	valid_1's auc: 0.779222	valid_1's binary_logloss: 0.239483
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.883068	training's binary_logloss: 0.201588	valid_1's auc: 0.779222	valid_1's binary_logloss: 0.239483

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis=1))[:, 1 ]
apps_all_test['TARGET'] = preds
# SK_ID_CURR과 TARGET 값만 csv 형태로 생성. 코랩 버전은 구글 드라이브 절대 경로로 입력  
default_dir = "/content/gdrive/My Drive"
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv(os.path.join(default_dir,'prev_baseline_tuning_01.csv'), index=False)

# %% [markdown]
# ### cross validation 으로 hyper parameter 재 tuning
# * 오히려 성능이 떨어질수도 있음.
# * 파이썬용으로 만들어진 LightGBM이므로 파라미터명은 lightGBM과는 약간 다름.

# %%
bayesian_params = {
    'max_depth': (6, 16), # 트리의 깊이
    'num_leaves': (24, 64), # 리프노드의 갯수 
    'min_data_in_leaf': (10, 200), # min_child_samples, 리프노드에 최소한의 필요한 데이터 갯수 (과적합제어 목표)
    'min_child_weight':(1, 50),
    'bagging_fraction':(0.5, 1.0), # subsample - 트리가 커져서 과적합되는 것을 제어하기 위해 데이터샘플링 비율 지정
    'feature_fraction': (0.5, 1.0), # colsample_bytree, 피처의 선택비율 지정
    'max_bin':(10, 500),
    'lambda_l2':(0.001, 10), # reg_lambda
    'lambda_l1': (0.01, 50) # reg_alpha
}

# %%
import lightgbm as lgb

# 파이썬 Wrapper용 lightgbm
train_data = lgb.Dataset(data=ftr_app, label=target_app, free_raw_data=False)
def lgb_roc_eval_cv(max_depth, num_leaves, min_data_in_leaf, min_child_weight, bagging_fraction, 
                 feature_fraction,  max_bin, lambda_l2, lambda_l1):   
    params = {
        "num_iterations":500, "learning_rate":0.02,
        'early_stopping_rounds':100, 'metric':'auc',
        'max_depth': int(round(max_depth)), #  호출 시 실수형 값이 들어오므로 실수형 하이퍼 파라미터는 정수형으로 변경 
        'num_leaves': int(round(num_leaves)), 
        'min_data_in_leaf': int(round(min_data_in_leaf)),
        'min_child_weight': int(round(min_child_weight)),
        'bagging_fraction': max(min(bagging_fraction, 1), 0), 
        'feature_fraction': max(min(feature_fraction, 1), 0),
        'max_bin':  max(int(round(max_bin)),10),
        'lambda_l2': max(lambda_l2,0),
        'lambda_l1': max(lambda_l1, 0)
    }
    # 파이썬 lightgbm의 cv 메소드를 사용- cross validation
    # cross_val_score도 쓸수도있지만.
    cv_reuslt = lgb.cv(params, train_data, nfold = 3, metics = ['auc'], verbose_eval=100, seed = 0, early_stopping_rounds=50)
    return max(cv_result['auc-mean'])

# %%
max_dict = lgbBO.res[np.argmax(np.array(target_list))]
print(max_dict)
# Out:
# {'target': 0.7780482186540827, 'params': {'colsample_bytree': 0.7436762853652641, 'max_bin': 494.6519941194128, 'max_depth': 14.273550154831288, 'min_child_samples': 25.784295891426886, 'min_child_weight': 2.6913774511864754, 'num_leaves': 57.965834800533756, 'reg_alpha': 2.4699153309230764, 'reg_lambda': 9.797178761741076, 'subsamples': 0.5823503102854222}}

# %%
def train_apps_all(apps_all_train):
    ftr_app = apps_all_train.drop(['SK_ID_CURR', 'TARGET'], axis=1)
    target_app = apps_all_train['TARGET']

    train_x, valid_x, train_y, valid_y = train_test_split(ftr_app, target_app, test_size=0.3, random_state=2020)
    print('train shape:', train_x.shape, 'valid shape:', valid_x.shape)
    clf = LGBMClassifier(
                nthread=4,
                n_estimators=1000,
                learning_rate=0.02,
                max_depth = 14,
                num_leaves=58,
                colsample_bytree=0.743,
                subsample= 0.582,
                max_bin=495,
                reg_alpha=2.47,
                reg_lambda = 9.797,
                min_child_weight=3,
                min_child_samples=26,
                silent=-1,
                verbose=-1,
                )

    clf.fit(train_x, train_y, eval_set=[(train_x, train_y), (valid_x, valid_y)], eval_metric= 'auc', verbose= 100, 
                early_stopping_rounds= 100)
    
    return clf

# %%
#1.파생변수 생성
#2.카테고리형을 레이블 인코딩
#3.훈련, 테스트용 데이터셋 분리 
#4.LightGBM 훈련
apps_all = get_apps_all_with_prev_agg(apps, prev)
apps_all = get_apps_all_encoded(apps_all)
apps_all_train, apps_all_test = get_apps_all_train_test(apps_all)
clf = train_apps_all(apps_all_train)
# Out:
# prev_agg shape: (338857, 41)
# apps_all before merge shape: (356255, 135)
# apps_all after merge with prev_agg shape: (356255, 176)
# train shape: (215257, 174) valid shape: (92254, 174)
# Training until validation scores don't improve for 100 rounds.
# [100]	training's auc: 0.778553	training's binary_logloss: 0.243214	valid_1's auc: 0.759151	valid_1's binary_logloss: 0.247681
# [200]	training's auc: 0.800338	training's binary_logloss: 0.233945	valid_1's auc: 0.769981	valid_1's binary_logloss: 0.242867
# [300]	training's auc: 0.816293	training's binary_logloss: 0.227839	valid_1's auc: 0.774466	valid_1's binary_logloss: 0.241216
# [400]	training's auc: 0.829769	training's binary_logloss: 0.222764	valid_1's auc: 0.77684	valid_1's binary_logloss: 0.240344
# [500]	training's auc: 0.84098	training's binary_logloss: 0.218495	valid_1's auc: 0.778048	valid_1's binary_logloss: 0.239917
# [600]	training's auc: 0.85073	training's binary_logloss: 0.214754	valid_1's auc: 0.778701	valid_1's binary_logloss: 0.239708
# [700]	training's auc: 0.859402	training's binary_logloss: 0.211282	valid_1's auc: 0.778945	valid_1's binary_logloss: 0.239617
# [800]	training's auc: 0.867595	training's binary_logloss: 0.208009	valid_1's auc: 0.779133	valid_1's binary_logloss: 0.239573
# [900]	training's auc: 0.875173	training's binary_logloss: 0.204875	valid_1's auc: 0.779334	valid_1's binary_logloss: 0.239515
# [1000]	training's auc: 0.882545	training's binary_logloss: 0.201815	valid_1's auc: 0.779361	valid_1's binary_logloss: 0.239508
# Did not meet early stopping. Best iteration is:
# [1000]	training's auc: 0.882545	training's binary_logloss: 0.201815	valid_1's auc: 0.779361	valid_1's binary_logloss: 0.239508

# %%
preds = clf.predict_proba(apps_all_test.drop('SK_ID_CURR', axis = 1))[:, 1]
apps_all_test['TARGET'] = preds

default_dir = "/content/gdrive/My Drive"
apps_all_test[['SK_ID_CURR', 'TARGET']].to_csv(os.path.join(default_dir, 'prev_baseline_tuning_02.csv'), index = False)
