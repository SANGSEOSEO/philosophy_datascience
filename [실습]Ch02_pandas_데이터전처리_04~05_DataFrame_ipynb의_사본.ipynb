# %% [markdown]
# <a href="https://colab.research.google.com/github/SANGSEOSEO/philosophy_datascience/blob/master/%5B%EC%8B%A4%EC%8A%B5%5DCh02_pandas_%EB%8D%B0%EC%9D%B4%ED%84%B0%EC%A0%84%EC%B2%98%EB%A6%AC_04~05_DataFrame_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# ## 실습에 활용한 예제

# %% [markdown]
# 1. [국내 아이돌 평판지수 (csv)](http://bit.ly/ds-korean-idol)
# 2. [국내 아이돌 연봉, 가족수 (csv)](http://bit.ly/ds-korean-idol-2)

# %% [markdown]
# ## DataFrame 로드

# %%
df = pd.read_csv('https://bit.ly/ds-korean-idol')
df2 = pd.read_csv('https://bit.ly/ds-korean-idol-2')

# %% [markdown]
# ## 1. DataFrame 합치기 (concat)

# %% [markdown]
# ### 1-1. Row 기준 합치기

# %%
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df_copy = df.copy()

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df_copy
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
# row에 합칠 때는 pd.concat에 합칠 데이터프레임을 list로 합쳐줍니다. row 기준으로 합칠 때는 **sort=False 옵션**을 주어 순서가 유지되도록 합니다.

# %%
 # 합치고 난 후에 순서가 유지되도록 
 # 행 인덱스도 그대로 유지
 # reset_index()를 해주면 인덱스를 초기화해준다.(기본적인 순차적인 인덱스로 초기화 eg) 0, 1, 2, 3, ....N
 pd.concat(objs=[df, df_copy], ignore_index=True, sort=False)
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
# 그런데, index가 꼬였습니다ㅠ reset_index() 로 인덱스를 초기화 해줄 수 있습니다.

# %%
df_concat = pd.concat(objs=[df, df_copy], sort=False)
df_concat
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
#   * reset_index()
#     -  옵션값 중 drop옵션의 값이 True이면 reset_index시 index를 추가하지 않는다.

# %% [markdown]
# 하지만, index라는 column이 추가 됩니다. 그럴때는 **drop=True** 옵션으로 새로 index column이 생성되지 않도록 만들어 줍니다.

# %%
df_concat.reset_index(drop=True)
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %% [markdown]
# ### 1-2. column 기준으로 합치기

# %% [markdown]
# 이번에는 column 기준으로 횡 방향으로 합치도록 하겠습니다.

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df2 = pd.read_csv('https://bit.ly/ds-korean-idol-2')
df2
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 1   지드래곤  3500    3
# 2   강다니엘  3200    4
# 3      뷔  3050    4
# 4     화사  4300    3
# 5     정국  2900    5
# 6     민현  3400    6
# 7     소연  4500    5
# 8      진  4200    4
# 9    하성운  4300    4
# 10    태연  3700    3
# 11   차은우  3850    5
# 12    백호  3900    4
# 13    JR  4100    3
# 14    슈가  4150    3

# %% [markdown]
# column을 기준으로 합치고자 할 때는 **axis=1 옵션**을 부여합니다

# %%
df_concat = pd.concat(objs=[df, df2], axis=1)
df_concat
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수    이름    연봉  가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260    지민  3000    3
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947  지드래곤  3500    3
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  강다니엘  3200    4
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501     뷔  3050    4
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928    화사  4300    3
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335    정국  2900    5
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792    민현  3400    6
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615    소연  4500    5
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308     진  4200    4
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489   하성운  4300    4
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661    태연  3700    3
# ...

# %%
# df2의 데이터 프레임에서 3번 인덱스 , 5번 인덱스 행을 삭제
df3 = df2.drop(labels=[3, 5], axis=0)

# %% [markdown]
# 행의 갯수가 맞지 않는 상태에서 column concat
#
# *   자동으로 NaN값으로 채워진다.
# *   3번째 인덱스와 5번째 인덱스를 삭제했으니 지금 로우갯수가 맞지 않는다.
# *   이 상태에서 concat를 하면?

# %%
pd.concat(objs=[df, df3], axis=1)
# Out:
#       이름     그룹      소속사  성별        생년월일  ...  혈액형   브랜드평판지수    이름      연봉  가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  ...    A  10523260    지민  3000.0  3.0
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  ...    A   9916947  지드래곤  3500.0  3.0
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  ...    A   8273745  강다니엘  3200.0  4.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  ...   AB   8073501   NaN     NaN  NaN
# 4     화사    마마무      RBW  여자  1995-07-23  ...    A   7650928    화사  4300.0  3.0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  ...    A   5208335   NaN     NaN  NaN
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  ...    O   4989792    민현  3400.0  6.0
# 7     소연    아이들       큐브  여자  1998-08-26  ...    B   4668615    소연  4500.0  5.0
# 8      진  방탄소년단      빅히트  남자  1992-12-04  ...    O   4570308     진  4200.0  4.0
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  ...    A   4036489   하성운  4300.0  4.0
# 10    태연   소녀시대       SM  여자  1989-03-09  ...    A   3918661    태연  3700.0  3.0
# ...

# %%
df3

# %% [markdown]
# ## 2. DataFrame 병합하기 (merge)

# %% [markdown]
# 이전에 봤던 concat과 merge는 단순 합치는 목적과 특정 기준(index)으로 합치느냐에
# 따라 용도가 다릅니다.
#
# * concat: row나 column 기준으로 단순하게 이어 붙히기
# * merge: 특정 고유한 키(unique id) 값을 기준으로 병합하기

# %%
df = pd.read_csv('https://bit.ly/ds-korean-idol')
df2 = pd.read_csv('https://bit.ly/ds-korean-idol-2')

# %%
df.head()
# Out:
#      이름     그룹  소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0    지민  방탄소년단  빅히트  남자  1995-10-13  173.6   A  10523260
# 1  지드래곤     빅뱅   YG  남자  1988-08-18  177.0   A   9916947
# 2  강다니엘    NaN  커넥트  남자  1996-12-10  180.0   A   8273745
# 3     뷔  방탄소년단  빅히트  남자  1995-12-30  178.0  AB   8073501
# 4    화사    마마무  RBW  여자  1995-07-23  162.1   A   7650928

# %%
df2.head()
# Out:
#      이름    연봉  가족수
# 0    지민  3000    3
# 1  지드래곤  3500    3
# 2  강다니엘  3200    4
# 3     뷔  3050    4
# 4    화사  4300    3

# %% [markdown]
# df와 df2는 **'이름' 이라는 column이 겹침**니다.
#
# 따라서, 우리는 '이름'을 기준으로 두 DataFrame을 **병합**할 수 있습니다.

# %% [markdown]
# **pd.merge(left, right, on='기준column', how='left')**
#
# * left와 right는 병합할 두 DataFrame을 대입합니다.
# * on 에는 병합의 기준이 되는 column을 넣어 줍니다.
# * how 에는 'left', 'right', 'inner', 'outer' 라는 4가지의 병합 방식중 한가지를 택합니다.

# %% [markdown]
# ### 2-1. left, right 방식

# %% [markdown]
# 먼저, 다음과 같이 df2 에서 5개의 데이터를 고의적으로 drop 해주겠습니다.

# %%
df2
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 1   지드래곤  3500    3
# 2   강다니엘  3200    4
# 3      뷔  3050    4
# 4     화사  4300    3
# 5     정국  2900    5
# 6     민현  3400    6
# 7     소연  4500    5
# 8      진  4200    4
# 9    하성운  4300    4
# 10    태연  3700    3
# 11   차은우  3850    5
# 12    백호  3900    4
# 13    JR  4100    3
# 14    슈가  4150    3

# %%
df_right = df2.drop([1, 3, 5, 7, 9], axis=0)
df_right
# Out:
#       이름    연봉  가족수
# 0     지민  3000    3
# 2   강다니엘  3200    4
# 4     화사  4300    3
# 6     민현  3400    6
# 8      진  4200    4
# 10    태연  3700    3
# 11   차은우  3850    5
# 12    백호  3900    4
# 13    JR  4100    3
# 14    슈가  4150    3

# %%
df_right = df_right.reset_index(drop=True)

# %%
df_right
# Out:
#      이름    연봉  가족수
# 0    지민  3000    3
# 1  강다니엘  3200    4
# 2    화사  4300    3
# 3    민현  3400    6
# 4     진  4200    4
# 5    태연  3700    3
# 6   차은우  3850    5
# 7    백호  3900    4
# 8    JR  4100    3
# 9    슈가  4150    3

# %%
df_right

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
pd.concat(objcs=[df, df_right], axis=0)
# Out:
#       이름     그룹      소속사  성별        생년월일  ...  혈액형   브랜드평판지수    이름      연봉  가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  ...    A  10523260    지민  3000.0  3.0
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  ...    A   9916947  강다니엘  3200.0  4.0
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  ...    A   8273745    화사  4300.0  3.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  ...   AB   8073501    민현  3400.0  6.0
# 4     화사    마마무      RBW  여자  1995-07-23  ...    A   7650928     진  4200.0  4.0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  ...    A   5208335    태연  3700.0  3.0
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  ...    O   4989792   차은우  3850.0  5.0
# 7     소연    아이들       큐브  여자  1998-08-26  ...    B   4668615    백호  3900.0  4.0
# 8      진  방탄소년단      빅히트  남자  1992-12-04  ...    O   4570308    JR  4100.0  3.0
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  ...    A   4036489    슈가  4150.0  3.0
# 10    태연   소녀시대       SM  여자  1989-03-09  ...    A   3918661   NaN     NaN  NaN
# ...

# %%
df

# %% [markdown]
# 병합할 2개의 DataFrame의 행의 갯수가 맞지 않습니다. 실 사례에서도 충분히 있을 법한 일입니다.

# %% [markdown]
# 'left' 옵션을 부여하면, left DataFrame에 키 값이 존재하면 해당 데이터를 유지하고, 병합한 right DataFrame의 값으 NaN이 대입 됩니다.

# %%
# `how='left'` 
pd.merge(left=df, right=df_right, on='이름', how='left' )
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수      연봉  가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  3000.0  3.0
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947     NaN  NaN
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  3200.0  4.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501     NaN  NaN
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  4300.0  3.0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335     NaN  NaN
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  3400.0  6.0
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615     NaN  NaN
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  4200.0  4.0
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     NaN  NaN
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  3700.0  3.0
# ...

# %% [markdown]
# 반대로 'right' 옵션을 부여하면 right DataFrame을 기준으로 병합하게 됩니다.
#
# 현재, left DataFrame이 더 많은 데이터를 보유하고 있으니, right를 기준으로 병합하면 DataFrame 사이즈가 줄어들겠네요.

# %%
pd.merge(left=df, right=df_right, how='right', on='이름')
# Out:
#      이름     그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수    연봉  가족수
# 0    지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260  3000    3
# 1  강다니엘    NaN   커넥트  남자  1996-12-10  180.0   A   8273745  3200    4
# 2    화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928  4300    3
# 3    민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792  3400    6
# 4     진  방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308  4200    4
# 5    태연   소녀시대    SM  여자  1989-03-09    NaN   A   3918661  3700    3
# 6   차은우   아스트로  판타지오  남자  1997-03-30  183.0   B   3506027  3850    5
# 7    백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654  3900    4
# 8    JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137  4100    3
# 9    슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442  4150    3

# %% [markdown]
# 위의 예제에서, right 를 기준으로 병합했기 때문에 DataFrame 사이즈가 줄어들었습니다.

# %% [markdown]
# ### 2-2. inner, outer 방식

# %% [markdown]
# * inner 방식은 두 DataFrame에 모두 키 값이 존재하는 경우만 병합합니다.
# * outer 방식은 하나의 DataFrame에 키 값이 존재하는 경우 모두 병합합니다.
# * outer 방식에서는 없는 값은 NaN으로 대입됩니다.

# %%
df

# %%
df_right

# %%
pd.merge(df, df_right,how='inner', on='이름')
# Out:
#      이름     그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수    연봉  가족수
# 0    지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260  3000    3
# 1  강다니엘    NaN   커넥트  남자  1996-12-10  180.0   A   8273745  3200    4
# 2    화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928  4300    3
# 3    민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792  3400    6
# 4     진  방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308  4200    4
# 5    태연   소녀시대    SM  여자  1989-03-09    NaN   A   3918661  3700    3
# 6   차은우   아스트로  판타지오  남자  1997-03-30  183.0   B   3506027  3850    5
# 7    백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654  3900    4
# 8    JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137  4100    3
# 9    슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442  4150    3

# %%
pd.merge(left=df, right=df_right, how='outer', on='이름')
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수      연봉  가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260  3000.0  3.0
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947     NaN  NaN
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745  3200.0  4.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501     NaN  NaN
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928  4300.0  3.0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335     NaN  NaN
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792  3400.0  6.0
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615     NaN  NaN
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308  4200.0  4.0
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489     NaN  NaN
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661  3700.0  3.0
# ...

# %% [markdown]
# ### 2-3. column명은 다르지만, 동일한 성질의 데이터 인 경우?
#   * how=`'outer'`
#   * left_on = `'컬럼명'`
#   * right_on = `'컬럼명'`

# %%
df
# Out:
#       이름     그룹      소속사  성별        생년월일      키 혈액형   브랜드평판지수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  173.6   A  10523260
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  177.0   A   9916947
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  180.0   A   8273745
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  178.0  AB   8073501
# 4     화사    마마무      RBW  여자  1995-07-23  162.1   A   7650928
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  178.0   A   5208335
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  182.3   O   4989792
# 7     소연    아이들       큐브  여자  1998-08-26    NaN   B   4668615
# 8      진  방탄소년단      빅히트  남자  1992-12-04  179.2   O   4570308
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  167.1   A   4036489
# 10    태연   소녀시대       SM  여자  1989-03-09    NaN   A   3918661
# 11   차은우   아스트로     판타지오  남자  1997-03-30  183.0   B   3506027
# 12    백호   뉴이스트     플레디스  남자  1995-07-21  175.0  AB   3301654
# 13    JR   뉴이스트     플레디스  남자  1995-06-08  176.0   O   3274137
# ...

# %%
df_right
# Out:
#      이름    연봉  가족수
# 0    지민  3000    3
# 1  강다니엘  3200    4
# 2    화사  4300    3
# 3    민현  3400    6
# 4     진  4200    4
# 5    태연  3700    3
# 6   차은우  3850    5
# 7    백호  3900    4
# 8    JR  4100    3
# 9    슈가  4150    3

# %%
df_right.columns=['성함', '년봉', '부양가족수']

# %%
df_right
# Out:
#      성함    년봉  부양가족수
# 0    지민  3000      3
# 1  강다니엘  3200      4
# 2    화사  4300      3
# 3    민현  3400      6
# 4     진  4200      4
# 5    태연  3700      3
# 6   차은우  3850      5
# 7    백호  3900      4
# 8    JR  4100      3
# 9    슈가  4150      3

# %% [markdown]
# df와 df_right를 병합하려고 했더니, df에서는 '이름', df_right에서는 '성함'으로 표기되어 **기준이 되는 column을 지정할 수 없습니다**.

# %% [markdown]
# 이럴 때는 left_on, right_on 옵션을 사용합니다.

# %%
pd.merge(left=df, right=df_right, how='inner', left_on='이름', right_on='성함')
# Out:
#      이름     그룹   소속사  성별        생년월일      키 혈액형   브랜드평판지수    성함    년봉  부양가족수
# 0    지민  방탄소년단   빅히트  남자  1995-10-13  173.6   A  10523260    지민  3000      3
# 1  강다니엘    NaN   커넥트  남자  1996-12-10  180.0   A   8273745  강다니엘  3200      4
# 2    화사    마마무   RBW  여자  1995-07-23  162.1   A   7650928    화사  4300      3
# 3    민현   뉴이스트  플레디스  남자  1995-08-09  182.3   O   4989792    민현  3400      6
# 4     진  방탄소년단   빅히트  남자  1992-12-04  179.2   O   4570308     진  4200      4
# 5    태연   소녀시대    SM  여자  1989-03-09    NaN   A   3918661    태연  3700      3
# 6   차은우   아스트로  판타지오  남자  1997-03-30  183.0   B   3506027   차은우  3850      5
# 7    백호   뉴이스트  플레디스  남자  1995-07-21  175.0  AB   3301654    백호  3900      4
# 8    JR   뉴이스트  플레디스  남자  1995-06-08  176.0   O   3274137    JR  4100      3
# 9    슈가  방탄소년단   빅히트  남자  1993-03-09  174.0   O   2925442    슈가  4150      3

# %%
pd.merge(left=df, right=df_right, how='outer', left_on='이름', right_on='성함')
# Out:
#       이름     그룹      소속사  성별        생년월일  ...  혈액형   브랜드평판지수    성함      년봉  부양가족수
# 0     지민  방탄소년단      빅히트  남자  1995-10-13  ...    A  10523260    지민  3000.0    3.0
# 1   지드래곤     빅뱅       YG  남자  1988-08-18  ...    A   9916947   NaN     NaN    NaN
# 2   강다니엘    NaN      커넥트  남자  1996-12-10  ...    A   8273745  강다니엘  3200.0    4.0
# 3      뷔  방탄소년단      빅히트  남자  1995-12-30  ...   AB   8073501   NaN     NaN    NaN
# 4     화사    마마무      RBW  여자  1995-07-23  ...    A   7650928    화사  4300.0    3.0
# 5     정국  방탄소년단      빅히트  남자  1997-09-01  ...    A   5208335   NaN     NaN    NaN
# 6     민현   뉴이스트     플레디스  남자  1995-08-09  ...    O   4989792    민현  3400.0    6.0
# 7     소연    아이들       큐브  여자  1998-08-26  ...    B   4668615   NaN     NaN    NaN
# 8      진  방탄소년단      빅히트  남자  1992-12-04  ...    O   4570308     진  4200.0    4.0
# 9    하성운     핫샷  스타크루이엔티  남자  1994-03-22  ...    A   4036489   NaN     NaN    NaN
# ...
